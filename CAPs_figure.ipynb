# %%
from nilearn.plotting import plot_stat_map
# %matplotlib inline

for i in range(len(CAPs)):
    fig,ax = plt.subplots(nrows=1, ncols=1,figsize=(24,6))
    plot_stat_map(analysis_functions.recover_3D(mask_file, CAPs[i]),bg_img='DSURQE.nii.gz', axes=ax, threshold=0.01, cut_coords=(0,1,2,3,4,5), display_mode='y')
    ax.set_title('CAP %s' % (str(i+1)), fontsize=17)
